# %% [markdown]
# ## **Questions based on Titanic Dataset:**
#
# To read the dataset as csv, use the below code:
#
# ```python
# import pandas as pd
#
# url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
# titanic_df = pd.read_csv(url)
# ```

# %%
import pandas as pd

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv"
titanic_df = pd.read_csv(url)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### `Q-1:` Using `groupby` make groups using the `"Pclass"` column and find out the average age and total number of missing values in the `"Age"` column for every group.

# %%
titanic_df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
titanic_df.groupby('Pclass')['Age'].apply(lambda x: x.isnull().sum())
# Out:
# Pclass
# 1     30
# 2     11
# 3    136
# Name: Age, dtype: int64

# %% [markdown]
# ### `Q-2:` Using `groupby` make groups using the `"Pclass"` column and fill every group's `"Embarked"` column's missing values with the mode value of that group. After that, print every group's `"Embarked"` column's value counts in ascending order.

# %%
titanic_df.groupby('Pclass')['Embarked'].apply(lambda x: x.fillna(x.mode().iloc[0])).value_counts()
# Out:
# Embarked
# S    646
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ### `Q-3:` Make groups based on `"Embarked"` column. And for each of this embarked group, make another group based on `"Pclass"` and find out the average fare (round off up to 2 decimal places) for each "Pclass" for each group of "Embarked".
#
# **Sample Output:**
#
# ```bash
# {'C': {1: 105, 2: 25, 3: 11},
#  'Q': {1: 90, 2: 12, 3: 11},
#  'S': {1: 70, 2: 20, 3: 15}}
# ```

# %%
titanic_df.groupby(['Embarked', 'Pclass'])['Fare'].mean().round(2).unstack().fillna(0).to_dict()
# Out:
# {1: {'C': 104.72, 'Q': 90.0, 'S': 70.36},
#  2: {'C': 25.36, 'Q': 12.35, 'S': 20.33},
#  3: {'C': 11.21, 'Q': 11.18, 'S': 14.64}}

# %%
titanic_df.groupby(['Pclass', 'Embarked'])['Fare'].mean().round(2).unstack().fillna(0).to_dict()
# Out:
# {'C': {1: 104.72, 2: 25.36, 3: 11.21},
#  'Q': {1: 90.0, 2: 12.35, 3: 11.18},
#  'S': {1: 70.36, 2: 20.33, 3: 14.64}}

# %% [markdown]
# ## **Questions Based on Fifa Worldcup - 2022 Dataset:**
#
# You can read the dataset by using the below sample code
#
# ```python
# import pandas as pd
#
# fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
# ```

# %%
import pandas as pd

fifa_df = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv")
fifa_df.head()
# Out:
#    Sl. No  Match No.     Team      Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar      Ecuador     A     0              40
# 1       2          1  Ecuador        Qatar     A     2              46
# 2       3          2  England         Iran     B     6              69
# 3       4          2     Iran      England     B     2              20
# 4       5          3  Senegal  Netherlands     A     0              39
#
#    Inside Penalty Area  Outside Penalty Area  Assists  ...  Fouls Against  \
# 0                    0                     0        0  ...             15
# 1                    2                     0        1  ...             15
# 2                    6                     0        6  ...              9
# 3                    2                     0        1  ...             14
# 4                    0                     0        0  ...             13
#
#    Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0         3     453               387       10                  5        1
# 1         4     484               419       26                 10        3
# 2         2     810               733       29                  9        8
# 3         2     232               156       11                  3        0
# 4         2     391               326       22                  8        6
#
#    Free Kicks  Penalties Scored  Pts
# 0          19                 0    0
# 1          17                 1    3
# 2          16                 0    3
# 3          10                 1    0
# 4          14                 0    0
#
# [5 rows x 38 columns]

# %% [markdown]
# ### `Q-4:` Perform `groupby` based on the `"Team"` column and then perform Z Normalization on top of the below columns of each group:
# 1. Passes
# 2. Passes Completed
# 3. Attempted Line Breaks
# 4. Completed Line Breaks
#
# You have to make a python function named `z_normalization` which takes two arguments:
#
# 1. *group:* Every group that you have created
# 2. *cols_to_perform:* This parameter takes a list of columns on which you have to perform the Z-Normalization.
#
# For this problem, you have to use th `apply()` method.
#
# $\Large Z \ - \ Normalization = \frac{X_i - \mu}{std} $
#
# After that find out the below values for each group:
# - minimum "Passess"
# - maximum "Passess"
# - minimum "Yellow Cards"
# - maximum "Yellow cards"
# - average "Yellow Cards"
# - maximum "Attempted Line Breaks"
# - minimum "Attempted Line Breaks"
# - standardard deviation of "Attempted Line Breaks"
# - average Possession

# %%
def z_normalization(group, cols_to_perform):
    group[cols_to_perform] = (group[cols_to_perform].values - group[cols_to_perform].mean()) / group[cols_to_perform].std()
    return group

# %%
fifa_df.groupby('Team').apply(z_normalization, ['Passes', 'Passes Completed', 'Attempted Line Breaks', 'Completed Line Breaks']).groupby('Team').agg({
    'Passes': ['min', 'max'],
    'Yellow Cards': ['min', 'max', 'mean'],
    'Attempted Line Breaks': ['min', 'max', 'std'],
    'Possession (%)': 'mean'
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0e1bd2e63c9a> in <cell line: 1>()
# ----> 1 fifa_df.groupby('Team').apply(z_normalization, ['Passes', 'Passes Completed', 'Attempted Line Breaks', 'Completed Line Breaks']).groupby('Team').agg({
#       2     'Passes': ['min', 'max'],
#       3     'Yellow Cards': ['min', 'max', 'mean'],
#       4     'Attempted Line Breaks': ['min', 'max', 'std'],
#       5     'Possession (%)': 'mean'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1768         with option_context("mode.chained_assignment", None):
#    1769             try:
# -> 1770                 result = self._python_apply_general(f, self._selected_obj)
#    1771             except TypeError:
#    1772                 # gh-20949
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1817             data after applying f
#    1818         """
# -> 1819         values, mutated = self.grouper.apply_groupwise(f, data, self.axis)
#    1820         if not_indexed_same is None:
#    1821             not_indexed_same = mutated
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in apply_groupwise(self, f, data, axis)
#     909             # group might be modified
#     910             group_axes = group.axes
# --> 911             res = f(group)
#     912             if not mutated and not _is_indexed_like(res, group_axes, axis):
#     913                 mutated = True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in f(g)
#    1756                 @wraps(func)
#    1757                 def f(g):
# -> 1758                     return func(g, *args, **kwargs)
#    1759
#    1760             else:
#
# <ipython-input-8-601b967e19db> in z_normalization(group, cols_to_perform)
#       1 def z_normalization(group, cols_to_perform):
# ----> 2     group[cols_to_perform] = (group[cols_to_perform].values - group[cols_to_perform].mean()) / group[cols_to_perform].std()
#       3     return group
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2100         self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2101     ):
# -> 2102         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    2103
#    2104     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     271
#     272     # for binary ops, use our custom dunder methods
# --> 273     result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     274     if result is not NotImplemented:
#     275         return result
#
# ops_dispatch.pyx in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __rsub__(self, other)
#     196     @unpack_zerodim_and_defer("__rsub__")
#     197     def __rsub__(self, other):
# --> 198         return self._arith_method(other, roperator.rsub)
#     199
#     200     @unpack_zerodim_and_defer("__mul__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _arith_method(self, other, op)
#    5817     def _arith_method(self, other, op):
#    5818         self, other = self._align_for_op(other)
# -> 5819         return base.IndexOpsMixin._arith_method(self, other, op)
#    5820
#    5821     def _align_for_op(self, right, align_asobject: bool = False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _arith_method(self, other, op)
#    1381             result = ops.arithmetic_op(lvalues, rvalues, op)
#    1382
# -> 1383         return self._construct_result(result, name=res_name)
#    1384
#    1385     def _construct_result(self, result, name):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _construct_result(self, result, name)
#    5913         #  JSONArray tests
#    5914         dtype = getattr(result, "dtype", None)
# -> 5915         out = self._constructor(result, index=self.index, dtype=dtype, copy=False)
#    5916         out = out.__finalize__(self)
#    5917
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     501             index = default_index(len(data))
#     502         elif is_list_like(data):
# --> 503             com.require_length_match(data, index)
#     504
#     505         # create/copy the manager
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     559     """
#     560     if len(data) != len(index):
# --> 561         raise ValueError(
#     562             "Length of values "
#     563             f"({len(data)}) "
#
# ValueError: Length of values (7) does not match length of index (4)

# %%
def z_normalization(group, cols_to_perform):
    for col in cols_to_perform:
        group[col] = (group[col] - group[col].mean()) / group[col].std()
    return group

cols_to_normalize = ['Passes', 'Passes Completed', 'Attempted Line Breaks', 'Completed Line Breaks']
normalized_df = fifa_df.groupby('Team').apply(z_normalization, cols_to_normalize)

# Reset the index to avoid ambiguity with the 'Team' column being both in the index and as a column
normalized_df = normalized_df.reset_index(drop=True)
result = normalized_df.groupby('Team').agg({
    'Passes': ['min', 'max'],
    'Yellow Cards': ['min', 'max', 'mean'],
    'Attempted Line Breaks': ['min', 'max', 'std'],
    'Possession (%)': 'mean'
})

result
# Out:
#                   Passes           Yellow Cards                \
#                      min       max          min max      mean
# Team
# Argentina      -1.510257  1.685214            0   8  2.285714
# Australia      -1.114789  0.932782            0   3  1.750000
# Belgium        -1.082696  0.888950            1   3  1.666667
# Brazil         -0.928871  1.609122            0   3  1.200000
# Cameroon       -0.875605  1.089713            1   5  2.666667
# Canada         -1.120897  0.800641            2   4  2.666667
# Costa Rica     -1.013178  0.986279            1   3  2.000000
# Croatia        -1.441280  1.093005            0   2  1.142857
# Denmark        -1.046208  0.946290            1   2  1.666667
# Ecuador        -0.883020  1.085876            0   2  1.000000
# England        -0.877731  1.705844            0   1  0.200000
# France         -1.219077  1.571019            0   3  1.142857
# Germany        -1.131449  0.765392            0   3  1.000000
# Ghana          -1.045786  0.946861            2   4  2.666667
# Iran           -0.820695  1.113800            2   3  2.333333
# Japan          -1.001479  0.979825            0   3  1.500000
# Korea Republic -1.157924  0.877868            1   2  1.500000
# Mexico         -0.918398  1.065342            1   4  2.333333
# Morocco        -1.384362  1.662218            0   3  1.285714
# Netherlands    -1.051749  1.428668            0   4  1.800000
# Poland         -0.694755  1.483035            1   3  1.750000
# Portugal       -1.646177  1.035658            0   3  1.200000
# Qatar          -1.147558  0.684833            0   4  2.333333
# Saudi Arabia   -0.667896  1.149691            2   6  4.666667
# Senegal        -1.214144  1.235077            1   3  1.750000
# Serbia         -1.089807  0.875419            2   7  4.000000
# Spain          -1.498758  0.554601            0   1  0.500000
# Switzerland    -1.469082  0.754945            1   4  2.250000
# Tunisia        -0.965692  1.031097            1   3  1.666667
# United States  -1.136338  0.860862            0   4  1.250000
# Uruguay        -0.931702  1.056570            1   3  2.000000
# Wales          -0.971590  1.026174            1   2  1.666667
#
#                Attempted Line Breaks                Possession (%)
#                                  min       max  std           mean
# Team
# Argentina                  -1.027917  1.757406  1.0      49.285714
# Australia                  -1.187623  0.961409  1.0      31.250000
# Belgium                    -0.832050  1.109400  1.0      49.000000
# Brazil                     -1.627519  1.085013  1.0      50.400000
# Cameroon                   -1.124661  0.788942  1.0      38.333333
# Canada                     -1.094819  0.865260  1.0      44.333333
# Costa Rica                 -1.154606  0.590132  1.0      27.333333
# Croatia                    -1.785063  1.187420  1.0      47.428571
# Denmark                    -1.000000  1.000000  1.0      51.333333
# Ecuador                    -0.979827  1.019020  1.0      42.666667
# England                    -1.172641  1.354603  1.0      57.200000
# France                     -1.327966  1.147789  1.0      44.857143
# Germany                    -0.959538  1.036065  1.0      53.000000
# Ghana                      -1.019578  0.979199  1.0      37.000000
# Iran                       -1.152297  0.640642  1.0      31.666667
# Japan                      -0.948495  1.377855  1.0      30.250000
# Korea Republic             -1.449814  0.840338  1.0      42.250000
# Mexico                     -1.154613  0.589590  1.0      46.666667
# Morocco                    -1.718366  1.006855  1.0      34.285714
# Netherlands                -1.222637  1.128588  1.0      44.000000
# Poland                     -1.493418  0.626272  1.0      32.000000
# Portugal                   -0.796941  1.655185  1.0      53.800000
# Qatar                      -0.815368  1.115767  1.0      39.333333
# Saudi Arabia               -1.022179  0.976238  1.0      36.666667
# Senegal                    -1.077420  1.343085  1.0      38.500000
# Serbia                     -0.916387  1.066614  1.0      42.666667
# Spain                      -0.905726  1.193911  1.0      67.000000
# Switzerland                -1.300880  1.024097  1.0      43.000000
# Tunisia                    -1.119304  0.805353  1.0      38.666667
# United States              -1.435367  0.767335  1.0      47.000000
# Uruguay                    -0.665750  1.149932  1.0      41.000000
# Wales                      -1.093756  0.867461  1.0      41.000000

# %% [markdown]
# ## **Questions on IPL wala dataset**
#
# ball by ball dataset - https://drive.google.com/file/d/1-kvv_9KCSAFWcrhS9WgTxSrURkRh6GNt/view?usp=share_link

# %% [markdown]
# ###`Q-5:` Find batsman in below category-
# * Highest score while chasing
# * Best Strike rate while chasing and have faced 100+ balls
#
#
# > Chasing mean team batting in second inning

# %%
ipl = pd.read_csv('ipl_deliveries.csv')
ipl.head()
# Out:
#         ID                            Team  innings  overs  ballnumber  \
# 0  1312200  Rajasthan RoyalsGujarat Titans        1      0           1
# 1  1312200  Rajasthan RoyalsGujarat Titans        1      0           2
# 2  1312200  Rajasthan RoyalsGujarat Titans        1      0           3
# 3  1312200  Rajasthan RoyalsGujarat Titans        1      0           4
# 4  1312200  Rajasthan RoyalsGujarat Titans        1      0           5
#
#         batter          bowler  non-striker extra_type  batsman_run  \
# 0  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 1  YBK Jaiswal  Mohammed Shami   JC Buttler    legbyes            0
# 2   JC Buttler  Mohammed Shami  YBK Jaiswal        NaN            1
# 3  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
# 4  YBK Jaiswal  Mohammed Shami   JC Buttler        NaN            0
#
#    extras_run  total_run  non_boundary  isWicketDelivery player_out kind  \
# 0           0          0             0                 0        NaN  NaN
# 1           1          1             0                 0        NaN  NaN
# 2           0          1             0                 0        NaN  NaN
# 3           0          0             0                 0        NaN  NaN
# 4           0          0             0                 0        NaN  NaN
#
#   fielders_involved       BattingTeam     BowlingTeam
# 0               NaN  Rajasthan Royals  Gujarat Titans
# 1               NaN  Rajasthan Royals  Gujarat Titans
# 2               NaN  Rajasthan Royals  Gujarat Titans
# 3               NaN  Rajasthan Royals  Gujarat Titans
# 4               NaN  Rajasthan Royals  Gujarat Titans

# %% [markdown]
# ###`Q-6` Most Successful bowler against any batsman. Find that pair of bowler and batsman.
# > Most Successful in terms of dissmissal. A bowler who have dissmissed any batsman most no of times. If any two pairs have same no of dissmisal, consider runs conceded by bowler to that batsman. Those who have concede lesser runs is more successful.

# %%
most_successful_pair = ipl.groupby(['bowler', 'batter']).agg(dismissals=('player_out', 'count'), runs_conceded=('batsman_run', 'sum')).reset_index().sort_values(by=['dismissals', 'runs_conceded'], ascending=[False, True]).head(1)
most_successful_pair
# Out:
#           bowler     batter  dismissals  runs_conceded
# 20710  SP Narine  RG Sharma           8            137

# %% [markdown]
# ###`Q-7`: Most successful batting pair in IPL. Batting pair who have scored most runs playing together.

# %%
ipl.groupby(['batter', 'bowler']).agg(runs=('total_run', 'sum')).reset_index().sort_values(by='runs', ascending=False).head(1)
# Out:
#          batter     bowler  runs
# 4690  DA Warner  SP Narine   183

# %% [markdown]
# ###`Q-8:` Make a dataframe for all batting pairs played together.
# ```
# Batsman1 Batsman2 Runs Avg StrikeRate
# ```
#
# > Just to ease this question you can count wide-balls for strike rate.

# %%
ipl.groupby(['Team', 'innings', 'overs']).agg(Batsman1=('batter', 'first'), Batsman2=('batter', 'last'), Runs=('total_run', 'sum'), Balls=('ballnumber', 'count')).assign(Avg=lambda x: x['Runs'] / x['Balls'], StrikeRate=lambda x: (x['Runs'] / x['Balls']) * 100).reset_index()[['Batsman1', 'Batsman2', 'Runs', 'Avg', 'StrikeRate']]
# Out:
#            Batsman1        Batsman2  Runs       Avg  StrikeRate
# 0      F du Plessis        PA Patel    40  0.888889   88.888889
# 1           M Vijay      SP Fleming    59  1.311111  131.111111
# 2           M Vijay      SP Fleming    60  1.428571  142.857143
# 3      F du Plessis      SP Fleming    54  1.148936  114.893617
# 4      F du Plessis        SK Raina    77  1.711111  171.111111
# ...             ...             ...   ...       ...         ...
# 7597  Shahbaz Ahmed       GH Vihari    66  1.375000  137.500000
# 7598  Shahbaz Ahmed  A Ashish Reddy    66  1.245283  124.528302
# 7599     GHS Garton       GH Vihari    48  1.230769  123.076923
# 7600    NLTC Perera        CL White    20  2.857143  285.714286
# 7601       CH Gayle        CH Gayle    15  2.500000  250.000000
#
# [7602 rows x 5 columns]
